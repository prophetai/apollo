# %%
import v20

# %%
oanda = v20.pricing
candleformat = 'midpoint'
instrument = 'USD_JPY'
data = oanda.get_prices(instrument='USD_JPY', candleFormat=candleformat)
# Out:
# ---------------------------------------------------------------------------
# OandaError                                Traceback (most recent call last)
# <ipython-input-5-4fdfe92a8b5e> in <module>
#       2 candleformat = 'midpoint'
#       3 instrument = 'USD_JPY'
# ----> 4 data = oanda.get_prices(instrument='USD_JPY', candleFormat=candleformat)
#       5
#
# /usr/local/lib/python3.7/site-packages/oandapy/oandapy.py in get_prices(self, **params)
#      29         """
#      30         endpoint = 'v1/prices'
# ---> 31         return self.request(endpoint, params=params)
#      32
#      33     def get_history(self, **params):
#
# /usr/local/lib/python3.7/site-packages/oandapy/oandapy.py in request(self, endpoint, method, params)
#     282         # error message
#     283         if response.status_code >= 400:
# --> 284             raise OandaError(content)
#     285
#     286         return content
#
# ...

# %%
data
# Out:
# {'instrument': 'USD_JPY',
#  'granularity': 'S5',
#  'candles': [{'time': '2019-05-31T19:49:30.000000Z',
#    'openMid': 108.398,
#    'highMid': 108.401,
#    'lowMid': 108.394,
#    'closeMid': 108.3985,
#    'volume': 24,
#    'complete': True},
#   {'time': '2019-05-31T19:49:35.000000Z',
#    'openMid': 108.3995,
#    'highMid': 108.4,
#    'lowMid': 108.395,
#    'closeMid': 108.396,
#    'volume': 10,
#    'complete': True},
#   {'time': '2019-05-31T19:49:40.000000Z',
#    'openMid': 108.395,
#    'highMid': 108.398,
#    'lowMid': 108.395,
#    'closeMid': 108.3975,
#    'volume': 3,
#    'complete': True},
#   {'time': '2019-05-31T19:49:45.000000Z',
#    'openMid': 108.3995,
#    'highMid': 108.404,
#    'lowMid': 108.4,
#    'closeMid': 108.403,
#    'volume': 12,
#    'complete': True},
#   {'time': '2019-05-31T19:49:50.000000Z',
#    'openMid': 108.405,
#    'highMid': 108.409,
#    'lowMid': 108.405,
#    'closeMid': 108.408,
#    'volume': 7,
#    'complete': True},
# ...
